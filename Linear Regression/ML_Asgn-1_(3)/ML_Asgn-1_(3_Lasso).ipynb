# %% [markdown]
# ## LASSO REGRESSION REGULARIZATION

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing and Plotting Train and Test data

# %%
X_train=pd.read_csv('ML_asgn1-train.csv')
X_test=pd.read_csv('ML_asgn1-test.csv')

x=X_train['Feature']
y=X_train['Label']

a=X_test['Feature']
b=X_test['Label']

# %%
train_error=[]
test_error=[]

# %%
m=1000              # Number of training examples 
alpha=0.05          # Learning Rate
iter=2000           # Iteration for gradient descent

# %% [markdown]
# ## Lasso Regression (n=2, lamda=0.25)

# %%
## Lasso Regression (n=2, lamda=0.25)

theta0=0.1
theta1=0.1
theta2=0.1

lamda=0.25

j_theta=[]
for i in range(0,iter):
    cost=0
    dtheta0=0
    dtheta1=0
    dtheta2=0
    for j in range(0,m):
        sigma=(theta0+theta1*x[j]+theta2*(x[j]**2)-y[j])
        cost=cost+(sigma**2)
        dtheta0=dtheta0+(sigma)
        dtheta1=dtheta1+(sigma)*x[j]
        dtheta2=dtheta2+(sigma)*(x[j]**2)
        
    cost=cost+lamda*(abs(theta0)+abs(theta1)+abs(theta2))
    cost=cost/(2*m)
    
    j_theta.append(cost)
    
    dtheta0=(dtheta0+(lamda/2)*(abs(theta0)/(theta0)))/m
    dtheta1=(dtheta1+(lamda/2)*(abs(theta1)/(theta1)))/m
    dtheta2=(dtheta2+(lamda/2)*(abs(theta2)/(theta2)))/m
    theta0=theta0-(alpha)*dtheta0
    theta1=theta1-(alpha)*dtheta1
    theta2=theta2-(alpha)*dtheta2

## Plot of J vs Iterations

plt.figure()
plt.plot(range(0,iter),np.array(j_theta))
plt.show()

print(theta0, theta1, theta2)

## Plot of Training Data and Model

y_pred_train=[]
for i in range(0,m):
    y_pred_train.append(theta0+theta1*x[i]+theta2*(x[i]**2))

plt.figure()
plt.scatter(x,y)
plt.scatter(x,y_pred_train)

## Train error

sum=0
for i in range(0,200):
    sum=sum+((y[i]-y_pred_train[i])**2)
sum=sum/200

train_error.append(sum)

print("Trained error = ", sum)

## Plot of Test Data and model

y_pred_test=[]
for i in range(0,200):
    y_pred_test.append(theta0+theta1*a[i]+theta2*(a[i]**2))


plt.figure()
plt.scatter(a,b)
plt.scatter(a,y_pred_test)   

## Test error

sum=0
for i in range(0,200):
    sum=sum+((b[i]-y_pred_test[i])**2)
sum=sum/200

test_error.append(sum)

print("Test error = ", sum)
# Out:
# 0.7908390623059005 -1.1700595632517206 -0.644381480356322
# Trained error =  0.22631375375020713
# Test error =  0.19370168821980538

# %% [markdown]
# ## Lasso Regression (n=2, lamda=0.50)

# %%
## Lasso Regression (n=2, lamda=0.50)

theta0=0.1
theta1=0.1
theta2=0.1

lamda=0.50

j_theta=[]
for i in range(0,iter):
    cost=0
    dtheta0=0
    dtheta1=0
    dtheta2=0
    for j in range(0,m):
        sigma=(theta0+theta1*x[j]+theta2*(x[j]**2)-y[j])
        cost=cost+(sigma**2)
        dtheta0=dtheta0+(sigma)
        dtheta1=dtheta1+(sigma)*x[j]
        dtheta2=dtheta2+(sigma)*(x[j]**2)
        
    cost=cost+lamda*(abs(theta0)+abs(theta1)+abs(theta2))
    cost=cost/(2*m)
    
    j_theta.append(cost)
    
    dtheta0=(dtheta0+(lamda/2)*(abs(theta0)/(theta0)))/m
    dtheta1=(dtheta1+(lamda/2)*(abs(theta1)/(theta1)))/m
    dtheta2=(dtheta2+(lamda/2)*(abs(theta2)/(theta2)))/m
    theta0=theta0-(alpha)*dtheta0
    theta1=theta1-(alpha)*dtheta1
    theta2=theta2-(alpha)*dtheta2

## Plot of J vs Iterations

plt.figure()
plt.plot(range(0,iter),np.array(j_theta))
plt.show()

print(theta0, theta1, theta2)

## Plot of Training Data and Model

y_pred_train=[]
for i in range(0,m):
    y_pred_train.append(theta0+theta1*x[i]+theta2*(x[i]**2))

plt.figure()
plt.scatter(x,y)
plt.scatter(x,y_pred_train)

## Train error

sum=0
for i in range(0,200):
    sum=sum+((y[i]-y_pred_train[i])**2)
sum=sum/200

train_error.append(sum)

print("Trained error = ", sum)

## Plot of Test Data and model

y_pred_test=[]
for i in range(0,200):
    y_pred_test.append(theta0+theta1*a[i]+theta2*(a[i]**2))


plt.figure()
plt.scatter(a,b)
plt.scatter(a,y_pred_test)   

## Test error

sum=0
for i in range(0,200):
    sum=sum+((b[i]-y_pred_test[i])**2)
sum=sum/200

test_error.append(sum)

print("Test error = ", sum)
# Out:
# 0.7896525174832583 -1.1679503687144646 -0.644480920947101
# Trained error =  0.2262900706940666
# Test error =  0.1936952864607479

# %% [markdown]
# ## Lasso Regression (n=2, lamda=0.75)

# %%
## Lasso Regression (n=2, lamda=0.75)

theta0=0.1
theta1=0.1
theta2=0.1

lamda=0.75

j_theta=[]
for i in range(0,iter):
    cost=0
    dtheta0=0
    dtheta1=0
    dtheta2=0
    for j in range(0,m):
        sigma=(theta0+theta1*x[j]+theta2*(x[j]**2)-y[j])
        cost=cost+(sigma**2)
        dtheta0=dtheta0+(sigma)
        dtheta1=dtheta1+(sigma)*x[j]
        dtheta2=dtheta2+(sigma)*(x[j]**2)
        
    cost=cost+lamda*(abs(theta0)+abs(theta1)+abs(theta2))
    cost=cost/(2*m)
    
    j_theta.append(cost)
    
    dtheta0=(dtheta0+(lamda/2)*(abs(theta0)/(theta0)))/m
    dtheta1=(dtheta1+(lamda/2)*(abs(theta1)/(theta1)))/m
    dtheta2=(dtheta2+(lamda/2)*(abs(theta2)/(theta2)))/m
    theta0=theta0-(alpha)*dtheta0
    theta1=theta1-(alpha)*dtheta1
    theta2=theta2-(alpha)*dtheta2


## Plot of J vs Iterations

plt.figure()
plt.plot(range(0,iter),np.array(j_theta))
plt.show()

print(theta0, theta1, theta2)

## Plot of Training Data and Model

y_pred_train=[]
for i in range(0,m):
    y_pred_train.append(theta0+theta1*x[i]+theta2*(x[i]**2))

plt.figure()
plt.scatter(x,y)
plt.scatter(x,y_pred_train)

## Train error

sum=0
for i in range(0,200):
    sum=sum+((y[i]-y_pred_train[i])**2)
sum=sum/200

train_error.append(sum)

print("Trained error = ", sum)

## Plot of Test Data and model

y_pred_test=[]
for i in range(0,200):
    y_pred_test.append(theta0+theta1*a[i]+theta2*(a[i]**2))


plt.figure()
plt.scatter(a,b)
plt.scatter(a,y_pred_test)   

## Test error

sum=0
for i in range(0,200):
    sum=sum+((b[i]-y_pred_test[i])**2)
sum=sum/200

test_error.append(sum)

print("Test error = ", sum)
# Out:
# 0.7884659726606162 -1.1658411741772088 -0.6445803615378792
# Trained error =  0.22626720539733103
# Test error =  0.1936896285454766

# %% [markdown]
# ## Lasso Regression (n=2, lamda=1.00)

# %%
## Lasso Regression (n=2, lamda=1)

theta0=0.1
theta1=0.1
theta2=0.1

lamda=1.00

j_theta=[]
for i in range(0,iter):
    cost=0
    dtheta0=0
    dtheta1=0
    dtheta2=0
    for j in range(0,m):
        sigma=(theta0+theta1*x[j]+theta2*(x[j]**2)-y[j])
        cost=cost+(sigma**2)
        dtheta0=dtheta0+(sigma)
        dtheta1=dtheta1+(sigma)*x[j]
        dtheta2=dtheta2+(sigma)*(x[j]**2)
        
    cost=cost+lamda*(abs(theta0)+abs(theta1)+abs(theta2))
    cost=cost/(2*m)
    
    j_theta.append(cost)
    
    dtheta0=(dtheta0+(lamda/2)*(abs(theta0)/(theta0)))/m
    dtheta1=(dtheta1+(lamda/2)*(abs(theta1)/(theta1)))/m
    dtheta2=(dtheta2+(lamda/2)*(abs(theta2)/(theta2)))/m
    theta0=theta0-(alpha)*dtheta0
    theta1=theta1-(alpha)*dtheta1
    theta2=theta2-(alpha)*dtheta2


## Plot of J vs Iterations

plt.figure()
plt.plot(range(0,iter),np.array(j_theta))
plt.show()

print(theta0, theta1, theta2)

## Plot of Training Data and Model

y_pred_train=[]
for i in range(0,m):
    y_pred_train.append(theta0+theta1*x[i]+theta2*(x[i]**2))

plt.figure()
plt.scatter(x,y)
plt.scatter(x,y_pred_train)

## Train error

sum=0
for i in range(0,200):
    sum=sum+((y[i]-y_pred_train[i])**2)
sum=sum/200

train_error.append(sum)

print("Trained error = ", sum)

## Plot of Test Data and model

y_pred_test=[]
for i in range(0,200):
    y_pred_test.append(theta0+theta1*a[i]+theta2*(a[i]**2))


plt.figure()
plt.scatter(a,b)
plt.scatter(a,y_pred_test)   

## Test error

sum=0
for i in range(0,200):
    sum=sum+((b[i]-y_pred_test[i])**2)
sum=sum/200

test_error.append(sum)

print("Test error = ", sum)
# Out:
# 0.7872794278379741 -1.1637319796399535 -0.6446798021286573
# Trained error =  0.22624515786000055
# Test error =  0.1936847144739917

# %% [markdown]
# ## Lasso Regression (n=9, lamda=0.25)

# %%
## Lasso Regression (n=9, lamda=0.25)

theta0=0.1
theta1=0.1
theta2=0.1
theta3=0.1
theta4=0.1
theta5=0.1
theta6=0.1
theta7=0.1
theta8=0.1
theta9=0.1

lamda=0.25

j_theta=[]
for i in range(0,iter):
    cost=0
    dtheta0=0
    dtheta1=0
    dtheta2=0
    dtheta3=0
    dtheta4=0
    dtheta5=0
    dtheta6=0
    dtheta7=0
    dtheta8=0
    dtheta9=0
    
    for j in range(0,m):
        sigma=(theta0+theta1*x[j]+theta2*(x[j]**2)+theta3*(x[j]**3)+theta4*(x[j]**4)+theta5*(x[j]**5)+theta6*(x[j]**6)+theta7*(x[j]**7)+theta8*(x[j]**8)+theta9*(x[j]**9)-y[j])
        cost=cost+(sigma**2)
        dtheta0=dtheta0+(sigma)
        dtheta1=dtheta1+(sigma)*x[j]
        dtheta2=dtheta2+(sigma)*(x[j]**2)
        dtheta3=dtheta3+(sigma)*(x[j]**3)
        dtheta4=dtheta4+(sigma)*(x[j]**4)
        dtheta5=dtheta5+(sigma)*(x[j]**5)
        dtheta6=dtheta6+(sigma)*(x[j]**6)
        dtheta7=dtheta7+(sigma)*(x[j]**7)
        dtheta8=dtheta8+(sigma)*(x[j]**8)
        dtheta9=dtheta9+(sigma)*(x[j]**9)
        
    cost=cost+lamda*(abs(theta0)+abs(theta1)+abs(theta2)+abs(theta3)+abs(theta4)+abs(theta5)+abs(theta6)+abs(theta7)+abs(theta8)+abs(theta9))    
    cost=cost/(2*m)
    j_theta.append(cost)
    
    dtheta0=(dtheta0+(lamda/2)*(abs(theta0)/(theta0)))/m
    dtheta1=(dtheta1+(lamda/2)*(abs(theta1)/(theta1)))/m
    dtheta2=(dtheta2+(lamda/2)*(abs(theta2)/(theta2)))/m
    dtheta3=(dtheta3+(lamda/2)*(abs(theta3)/(theta3)))/m
    dtheta4=(dtheta4+(lamda/2)*(abs(theta4)/(theta4)))/m
    dtheta5=(dtheta5+(lamda/2)*(abs(theta5)/(theta5)))/m
    dtheta6=(dtheta6+(lamda/2)*(abs(theta6)/(theta6)))/m
    dtheta7=(dtheta7+(lamda/2)*(abs(theta7)/(theta7)))/m
    dtheta8=(dtheta8+(lamda/2)*(abs(theta8)/(theta8)))/m
    dtheta9=(dtheta9+(lamda/2)*(abs(theta9)/(theta9)))/m
        
    theta0=theta0-(alpha)*dtheta0
    theta1=theta1-(alpha)*dtheta1
    theta2=theta2-(alpha)*dtheta2
    theta3=theta3-(alpha)*dtheta3
    theta4=theta4-(alpha)*dtheta4
    theta5=theta5-(alpha)*dtheta5
    theta6=theta6-(alpha)*dtheta6
    theta7=theta7-(alpha)*dtheta7
    theta8=theta8-(alpha)*dtheta8
    theta9=theta9-(alpha)*dtheta9
    
## Plot of J vs Iterations

plt.figure()
plt.plot(range(0,iter),np.array(j_theta))
plt.show()

print(theta0, theta1, theta2, theta3, theta4, theta5, theta6, theta7, theta8, theta9)

## Plot of Training Data and Model

y_pred_train=[]
for i in range(0,m):
    y_pred_train.append(theta0+theta1*x[i]+theta2*(x[i]**2)+theta3*(x[i]**3)+theta4*(x[i]**4)+theta5*(x[i]**5)+theta6*(x[i]**6)+theta7*(x[i]**7)+theta8*(x[i]**8)+theta9*(x[i]**9))

plt.figure()
plt.scatter(x,y)
plt.scatter(x,y_pred_train)

## Train error

sum=0
for i in range(0,200):
    sum=sum+((y[i]-y_pred_train[i])**2)
sum=sum/200

train_error.append(sum)

print("Trained error = ", sum)

## Plot of Test Data and model

y_pred_test=[]
for i in range(0,200):
    y_pred_test.append(theta0+theta1*a[i]+theta2*(a[i]**2)+theta3*(a[i]**3)+theta4*(a[i]**4)+theta5*(a[i]**5)+theta6*(a[i]**6)+theta7*(a[i]**7)+theta8*(a[i]**8)+theta9*(x[i]**9))


plt.figure()
plt.scatter(a,b)
plt.scatter(a,y_pred_test)   

## Test error

sum=0
for i in range(0,200):
    sum=sum+((b[i]-y_pred_test[i])**2)
sum=sum/200

test_error.append(sum)

print("Test error = ", sum)
# Out:
# 0.9332785990904199 -0.9969949987366907 -1.4725412928117305 -0.9730032047646996 -0.370331392380177 0.10063937809982432 0.4541157919304941 0.6991948260526846 0.8620924916112016 0.9664294409813432
# Trained error =  0.10540870530046632
# Test error =  0.18804521193625548

# %% [markdown]
# ## Lasso Regression (n=9, lamda=0.5)

# %%
## Lasso Regression (n=9, lamda=0.5)

theta0=0.1
theta1=0.1
theta2=0.1
theta3=0.1
theta4=0.1
theta5=0.1
theta6=0.1
theta7=0.1
theta8=0.1
theta9=0.1

lamda=0.5

j_theta=[]
for i in range(0,iter):
    cost=0
    dtheta0=0
    dtheta1=0
    dtheta2=0
    dtheta3=0
    dtheta4=0
    dtheta5=0
    dtheta6=0
    dtheta7=0
    dtheta8=0
    dtheta9=0
    
    for j in range(0,m):
        sigma=(theta0+theta1*x[j]+theta2*(x[j]**2)+theta3*(x[j]**3)+theta4*(x[j]**4)+theta5*(x[j]**5)+theta6*(x[j]**6)+theta7*(x[j]**7)+theta8*(x[j]**8)+theta9*(x[j]**9)-y[j])
        cost=cost+(sigma**2)
        dtheta0=dtheta0+(sigma)
        dtheta1=dtheta1+(sigma)*x[j]
        dtheta2=dtheta2+(sigma)*(x[j]**2)
        dtheta3=dtheta3+(sigma)*(x[j]**3)
        dtheta4=dtheta4+(sigma)*(x[j]**4)
        dtheta5=dtheta5+(sigma)*(x[j]**5)
        dtheta6=dtheta6+(sigma)*(x[j]**6)
        dtheta7=dtheta7+(sigma)*(x[j]**7)
        dtheta8=dtheta8+(sigma)*(x[j]**8)
        dtheta9=dtheta9+(sigma)*(x[j]**9)
        
    cost=cost+lamda*(abs(theta0)+abs(theta1)+abs(theta2)+abs(theta3)+abs(theta4)+abs(theta5)+abs(theta6)+abs(theta7)+abs(theta8)+abs(theta9))    
    cost=cost/(2*m)
    j_theta.append(cost)
    
    dtheta0=(dtheta0+(lamda/2)*(abs(theta0)/(theta0)))/m
    dtheta1=(dtheta1+(lamda/2)*(abs(theta1)/(theta1)))/m
    dtheta2=(dtheta2+(lamda/2)*(abs(theta2)/(theta2)))/m
    dtheta3=(dtheta3+(lamda/2)*(abs(theta3)/(theta3)))/m
    dtheta4=(dtheta4+(lamda/2)*(abs(theta4)/(theta4)))/m
    dtheta5=(dtheta5+(lamda/2)*(abs(theta5)/(theta5)))/m
    dtheta6=(dtheta6+(lamda/2)*(abs(theta6)/(theta6)))/m
    dtheta7=(dtheta7+(lamda/2)*(abs(theta7)/(theta7)))/m
    dtheta8=(dtheta8+(lamda/2)*(abs(theta8)/(theta8)))/m
    dtheta9=(dtheta9+(lamda/2)*(abs(theta9)/(theta9)))/m
        
    theta0=theta0-(alpha)*dtheta0
    theta1=theta1-(alpha)*dtheta1
    theta2=theta2-(alpha)*dtheta2
    theta3=theta3-(alpha)*dtheta3
    theta4=theta4-(alpha)*dtheta4
    theta5=theta5-(alpha)*dtheta5
    theta6=theta6-(alpha)*dtheta6
    theta7=theta7-(alpha)*dtheta7
    theta8=theta8-(alpha)*dtheta8
    theta9=theta9-(alpha)*dtheta9
    
## Plot of J vs Iterations

plt.figure()
plt.plot(range(0,iter),np.array(j_theta))
plt.show()

print(theta0, theta1, theta2, theta3, theta4, theta5, theta6, theta7, theta8, theta9)

## Plot of Training Data and Model

y_pred_train=[]
for i in range(0,m):
    y_pred_train.append(theta0+theta1*x[i]+theta2*(x[i]**2)+theta3*(x[i]**3)+theta4*(x[i]**4)+theta5*(x[i]**5)+theta6*(x[i]**6)+theta7*(x[i]**7)+theta8*(x[i]**8)+theta9*(x[i]**9))

plt.figure()
plt.scatter(x,y)
plt.scatter(x,y_pred_train)

## Train error

sum=0
for i in range(0,200):
    sum=sum+((y[i]-y_pred_train[i])**2)
sum=sum/200

train_error.append(sum)

print("Trained error = ", sum)

## Plot of Test Data and model

y_pred_test=[]
for i in range(0,200):
    y_pred_test.append(theta0+theta1*a[i]+theta2*(a[i]**2)+theta3*(a[i]**3)+theta4*(a[i]**4)+theta5*(a[i]**5)+theta6*(a[i]**6)+theta7*(a[i]**7)+theta8*(a[i]**8)+theta9*(x[i]**9))


plt.figure()
plt.scatter(a,b)
plt.scatter(a,y_pred_test)   

## Test error

sum=0
for i in range(0,200):
    sum=sum+((b[i]-y_pred_test[i])**2)
sum=sum/200

test_error.append(sum)

print("Test error = ", sum)
# Out:
# 0.9315848469001228 -0.9974627969916106 -1.4698386782973998 -0.965377067110615 -0.3586479986356608 0.0955120655308914 0.4480677683281473 0.6937088418207671 0.857013557406835 0.9621851059854134
# Trained error =  0.10560250607689442
# Test error =  0.1874620946169501

# %% [markdown]
# ## Lasso Regression (n=9, lamda=0.75)

# %%
## Lasso Regression (n=9, lamda=0.75)

theta0=0.1
theta1=0.1
theta2=0.1
theta3=0.1
theta4=0.1
theta5=0.1
theta6=0.1
theta7=0.1
theta8=0.1
theta9=0.1

lamda=0.75

j_theta=[]
for i in range(0,iter):
    cost=0
    dtheta0=0
    dtheta1=0
    dtheta2=0
    dtheta3=0
    dtheta4=0
    dtheta5=0
    dtheta6=0
    dtheta7=0
    dtheta8=0
    dtheta9=0
    
    for j in range(0,m):
        sigma=(theta0+theta1*x[j]+theta2*(x[j]**2)+theta3*(x[j]**3)+theta4*(x[j]**4)+theta5*(x[j]**5)+theta6*(x[j]**6)+theta7*(x[j]**7)+theta8*(x[j]**8)+theta9*(x[j]**9)-y[j])
        cost=cost+(sigma**2)
        dtheta0=dtheta0+(sigma)
        dtheta1=dtheta1+(sigma)*x[j]
        dtheta2=dtheta2+(sigma)*(x[j]**2)
        dtheta3=dtheta3+(sigma)*(x[j]**3)
        dtheta4=dtheta4+(sigma)*(x[j]**4)
        dtheta5=dtheta5+(sigma)*(x[j]**5)
        dtheta6=dtheta6+(sigma)*(x[j]**6)
        dtheta7=dtheta7+(sigma)*(x[j]**7)
        dtheta8=dtheta8+(sigma)*(x[j]**8)
        dtheta9=dtheta9+(sigma)*(x[j]**9)
        
    cost=cost+lamda*(abs(theta0)+abs(theta1)+abs(theta2)+abs(theta3)+abs(theta4)+abs(theta5)+abs(theta6)+abs(theta7)+abs(theta8)+abs(theta9))    
    cost=cost/(2*m)
    j_theta.append(cost)
    
    dtheta0=(dtheta0+(lamda/2)*(abs(theta0)/(theta0)))/m
    dtheta1=(dtheta1+(lamda/2)*(abs(theta1)/(theta1)))/m
    dtheta2=(dtheta2+(lamda/2)*(abs(theta2)/(theta2)))/m
    dtheta3=(dtheta3+(lamda/2)*(abs(theta3)/(theta3)))/m
    dtheta4=(dtheta4+(lamda/2)*(abs(theta4)/(theta4)))/m
    dtheta5=(dtheta5+(lamda/2)*(abs(theta5)/(theta5)))/m
    dtheta6=(dtheta6+(lamda/2)*(abs(theta6)/(theta6)))/m
    dtheta7=(dtheta7+(lamda/2)*(abs(theta7)/(theta7)))/m
    dtheta8=(dtheta8+(lamda/2)*(abs(theta8)/(theta8)))/m
    dtheta9=(dtheta9+(lamda/2)*(abs(theta9)/(theta9)))/m
        
    theta0=theta0-(alpha)*dtheta0
    theta1=theta1-(alpha)*dtheta1
    theta2=theta2-(alpha)*dtheta2
    theta3=theta3-(alpha)*dtheta3
    theta4=theta4-(alpha)*dtheta4
    theta5=theta5-(alpha)*dtheta5
    theta6=theta6-(alpha)*dtheta6
    theta7=theta7-(alpha)*dtheta7
    theta8=theta8-(alpha)*dtheta8
    theta9=theta9-(alpha)*dtheta9
    
## Plot of J vs Iterations

plt.figure()
plt.plot(range(0,iter),np.array(j_theta))
plt.show()

print(theta0, theta1, theta2, theta3, theta4, theta5, theta6, theta7, theta8, theta9)

## Plot of Training Data and Model

y_pred_train=[]
for i in range(0,m):
    y_pred_train.append(theta0+theta1*x[i]+theta2*(x[i]**2)+theta3*(x[i]**3)+theta4*(x[i]**4)+theta5*(x[i]**5)+theta6*(x[i]**6)+theta7*(x[i]**7)+theta8*(x[i]**8)+theta9*(x[i]**9))

plt.figure()
plt.scatter(x,y)
plt.scatter(x,y_pred_train)

## Train error

sum=0
for i in range(0,200):
    sum=sum+((y[i]-y_pred_train[i])**2)
sum=sum/200

train_error.append(sum)

print("Trained error = ", sum)

## Plot of Test Data and model

y_pred_test=[]
for i in range(0,200):
    y_pred_test.append(theta0+theta1*a[i]+theta2*(a[i]**2)+theta3*(a[i]**3)+theta4*(a[i]**4)+theta5*(a[i]**5)+theta6*(a[i]**6)+theta7*(a[i]**7)+theta8*(a[i]**8)+theta9*(x[i]**9))


plt.figure()
plt.scatter(a,b)
plt.scatter(a,y_pred_test)   

## Test error

sum=0
for i in range(0,200):
    sum=sum+((b[i]-y_pred_test[i])**2)
sum=sum/200

test_error.append(sum)

print("Test error = ", sum)
# Out:
# 0.9298896752326822 -0.9979325728870675 -1.467121457392597 -0.9577264788778919 -0.34693526466382807 0.0902411046265909 0.4420264891648891 0.6882415960306251 0.8519648696669259 0.9579697790699842
# Trained error =  0.1058033217232215
# Test error =  0.18689329153340523

# %% [markdown]
# ## Lasso Regression (n=9, lamda=1.00)

# %%
## Lasso Regression (n=9, lamda=1.00)

theta0=0.1
theta1=0.1
theta2=0.1
theta3=0.1
theta4=0.1
theta5=0.1
theta6=0.1
theta7=0.1
theta8=0.1
theta9=0.1

lamda=1.00

j_theta=[]
for i in range(0,iter):
    cost=0
    dtheta0=0
    dtheta1=0
    dtheta2=0
    dtheta3=0
    dtheta4=0
    dtheta5=0
    dtheta6=0
    dtheta7=0
    dtheta8=0
    dtheta9=0
    
    for j in range(0,m):
        sigma=(theta0+theta1*x[j]+theta2*(x[j]**2)+theta3*(x[j]**3)+theta4*(x[j]**4)+theta5*(x[j]**5)+theta6*(x[j]**6)+theta7*(x[j]**7)+theta8*(x[j]**8)+theta9*(x[j]**9)-y[j])
        cost=cost+(sigma**2)
        dtheta0=dtheta0+(sigma)
        dtheta1=dtheta1+(sigma)*x[j]
        dtheta2=dtheta2+(sigma)*(x[j]**2)
        dtheta3=dtheta3+(sigma)*(x[j]**3)
        dtheta4=dtheta4+(sigma)*(x[j]**4)
        dtheta5=dtheta5+(sigma)*(x[j]**5)
        dtheta6=dtheta6+(sigma)*(x[j]**6)
        dtheta7=dtheta7+(sigma)*(x[j]**7)
        dtheta8=dtheta8+(sigma)*(x[j]**8)
        dtheta9=dtheta9+(sigma)*(x[j]**9)
        
    cost=cost+lamda*(abs(theta0)+abs(theta1)+abs(theta2)+abs(theta3)+abs(theta4)+abs(theta5)+abs(theta6)+abs(theta7)+abs(theta8)+abs(theta9))    
    cost=cost/(2*m)
    j_theta.append(cost)
    
    dtheta0=(dtheta0+(lamda/2)*(abs(theta0)/(theta0)))/m
    dtheta1=(dtheta1+(lamda/2)*(abs(theta1)/(theta1)))/m
    dtheta2=(dtheta2+(lamda/2)*(abs(theta2)/(theta2)))/m
    dtheta3=(dtheta3+(lamda/2)*(abs(theta3)/(theta3)))/m
    dtheta4=(dtheta4+(lamda/2)*(abs(theta4)/(theta4)))/m
    dtheta5=(dtheta5+(lamda/2)*(abs(theta5)/(theta5)))/m
    dtheta6=(dtheta6+(lamda/2)*(abs(theta6)/(theta6)))/m
    dtheta7=(dtheta7+(lamda/2)*(abs(theta7)/(theta7)))/m
    dtheta8=(dtheta8+(lamda/2)*(abs(theta8)/(theta8)))/m
    dtheta9=(dtheta9+(lamda/2)*(abs(theta9)/(theta9)))/m
        
    theta0=theta0-(alpha)*dtheta0
    theta1=theta1-(alpha)*dtheta1
    theta2=theta2-(alpha)*dtheta2
    theta3=theta3-(alpha)*dtheta3
    theta4=theta4-(alpha)*dtheta4
    theta5=theta5-(alpha)*dtheta5
    theta6=theta6-(alpha)*dtheta6
    theta7=theta7-(alpha)*dtheta7
    theta8=theta8-(alpha)*dtheta8
    theta9=theta9-(alpha)*dtheta9
    
## Plot of J vs Iterations

plt.figure()
plt.plot(range(0,iter),np.array(j_theta))
plt.show()

print(theta0, theta1, theta2, theta3, theta4, theta5, theta6, theta7, theta8, theta9)

## Plot of Training Data and Model

y_pred_train=[]
for i in range(0,m):
    y_pred_train.append(theta0+theta1*x[i]+theta2*(x[i]**2)+theta3*(x[i]**3)+theta4*(x[i]**4)+theta5*(x[i]**5)+theta6*(x[i]**6)+theta7*(x[i]**7)+theta8*(x[i]**8)+theta9*(x[i]**9))

plt.figure()
plt.scatter(x,y)
plt.scatter(x,y_pred_train)

## Train error

sum=0
for i in range(0,200):
    sum=sum+((y[i]-y_pred_train[i])**2)
sum=sum/200

train_error.append(sum)

print("Trained error = ", sum)

## Plot of Test Data and model

y_pred_test=[]
for i in range(0,200):
    y_pred_test.append(theta0+theta1*a[i]+theta2*(a[i]**2)+theta3*(a[i]**3)+theta4*(a[i]**4)+theta5*(a[i]**5)+theta6*(a[i]**6)+theta7*(a[i]**7)+theta8*(a[i]**8)+theta9*(x[i]**9))


plt.figure()
plt.scatter(a,b)
plt.scatter(a,y_pred_test)   

## Test error

sum=0
for i in range(0,200):
    sum=sum+((b[i]-y_pred_test[i])**2)
sum=sum/200

test_error.append(sum)

print("Test error = ", sum)
# Out:
# 0.928193293017519 -0.9984013645795183 -1.4643951765337515 -0.9500628115065688 -0.33520793859509174 0.08485994836320718 0.43602457897510594 0.6827879773127594 0.846928941273613 0.9537663134534463
# Trained error =  0.10601108816559898
# Test error =  0.1863354285045779

# %%
train_error
# Out:
# [0.22631375375020713,
#  0.2262900706940666,
#  0.22626720539733103,
#  0.22624515786000055,
#  0.10540870530046632,
#  0.10560250607689442,
#  0.1058033217232215,
#  0.10601108816559898]

# %%
test_error
# Out:
# [0.19370168821980538,
#  0.1936952864607479,
#  0.1936896285454766,
#  0.1936847144739917,
#  0.18804521193625548,
#  0.1874620946169501,
#  0.18689329153340523,
#  0.1863354285045779]

# %% [markdown]
# ## Plot of Lasso Regression train & test error

# %%
# Plot of train and test error for n=2 at different lamda


lamda=[0.25,0.5,0.75,1.0]

plt.figure()
plt.plot(lamda,train_error[0:4],label='train_error')
plt.plot(lamda,test_error[0:4],label='test_error')
plt.xlabel('lamda')
plt.ylabel('train_error/test_error')
plt.legend()
plt.show()

# %%
# Plot of train and test error for n=8 at different lamda

lamda=[0.25,0.5,0.75,1.0]

plt.figure()
plt.plot(lamda,train_error[4:8],label='train_error')
plt.plot(lamda,test_error[4:8],label='test_error')
plt.xlabel('lamda')
plt.ylabel('train_error/test_error')
plt.legend()
plt.show()
